# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2021-06-10 08:37:58--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_frontalface_default.xml.1’
#
# haarcascade_frontal     [  <=>               ]   8.27M  21.9MB/s    in 0.4s
#
# 2021-06-10 08:38:01 (21.9 MB/s) - ‘haarcascade_frontalface_default.xml.1’ saved [8675338]

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2021-06-10 08:38:04--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_eye.xml.1’
#
# haarcascade_eye.xml     [  <=>               ]   3.08M  10.1MB/s    in 0.3s
#
# 2021-06-10 08:38:05 (10.1 MB/s) - ‘haarcascade_eye.xml.1’ saved [3234350]

# %%
# !wget https://www.suntiros.com/wp-content/uploads/2017/11/Prabhas-Pics-At-Award-Show.jpg
# Out:
# --2021-06-10 08:38:08--  https://www.suntiros.com/wp-content/uploads/2017/11/Prabhas-Pics-At-Award-Show.jpg
# Resolving www.suntiros.com (www.suntiros.com)... 159.65.149.42
# Connecting to www.suntiros.com (www.suntiros.com)|159.65.149.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246291 (241K) [image/jpeg]
# Saving to: ‘Prabhas-Pics-At-Award-Show.jpg.2’
#
# Prabhas-Pics-At-Awa 100%[===================>] 240.52K   260KB/s    in 0.9s
#
# 2021-06-10 08:38:10 (260 KB/s) - ‘Prabhas-Pics-At-Award-Show.jpg.2’ saved [246291/246291]

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# %%
img = cv2.imread('Prabhas-Pics-At-Award-Show.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 9)
print(faces)
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),20)
roi_gray = gray[y:y+h, x:x+w]
roi_color = img[y:y+h, x:x+w]
eyes = eye_cascade.detectMultiScale(roi_gray)
for (ex,ey,ew,eh) in eyes:
  cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),20)
plt.imshow(img)
plt.show()
# Out:
# [[200 286 479 479]]
